# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

df=pd.read_excel('mlpaper.xlsx')

X = df.drop(columns = ['power'])

y = df['power']

X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.15,random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler()

# %%
X_train=scaler.transform(X_train)
X_test=scaler.transform(X_test)
from sklearn.neural_network import MLPRegressor
nn=MLPRegressor(hidden_layer_sizes=(1000,100,), activation='relu', max_iter=100,solver='adam')
nn.fit(X_train,y_train)
# Out:
# /Users/akashlayek/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/akashlayek/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# MLPRegressor(hidden_layer_sizes=(1000, 100), max_iter=100)

# %%
y_predict = nn.predict(X_test)
y_predict_train = nn.predict(X_train)

# %%
plt.scatter(y_test, y_predict)
plt.xlabel('Actual Power')
plt.ylabel('Predicted Power')
plt.title('Actual vs Predicted Power')
plt.show()

# %%
residuals = y_test - y_pred
plt.scatter(y_pred, residuals)
plt.xlabel('Predicted Power')
plt.ylabel('Residuals')
plt.title('Residual Plot')
plt.axhline(y=0, color='r', linestyle='--')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 residuals = y_test - y_pred
#       2 plt.scatter(y_pred, residuals)
#       3 plt.xlabel('Predicted Power')
#
# NameError: name 'y_pred' is not defined

# %%
X_train
# Out:
# array([[ 0.00000000e+00, -1.65309285e-01],
#        [ 4.68346201e-07, -1.65094673e-01],
#        [ 5.56131000e-07, -1.65105941e-01],
#        ...,
#        [ 0.00000000e+00, -1.65328123e-01],
#        [ 5.93672507e-07, -1.65132877e-01],
#        [ 0.00000000e+00, -1.65109814e-01]])
